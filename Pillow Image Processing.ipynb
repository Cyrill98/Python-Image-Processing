# %% [markdown]
# <a href="https://colab.research.google.com/github/Cyrill98/Python-Image-Processing/blob/main/Pillow%20Image%20Processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Image Processing using Pillow Library**

# %%
from PIL import Image
from matplotlib import pyplot as plt

# %%
image = Image.open('SampleCell.jpg')

# %%
print(image.format)
# Out:
# JPEG

# %%
print(image.mode)
# Out:
# RGB

# %%
print(image.size)
# Out:
# (223, 226)

# %% [markdown]
# # **Resize Image**

# %%
resize_image = image.resize((150,150))
plt.imshow(resize_image)

# %% [markdown]
# # **Crop Image**

# %%
cropped_image = image.crop((0,0, 100, 100))
plt.imshow(cropped_image)

# %% [markdown]
# # **Rotate Image**

# %%
rotate_image = image.rotate(40)
plt.imshow(rotate_image)

# %% [markdown]
# # **Convert RGB image to grayscale**

# %%
grey_image = image.convert("L")
plt.imshow(grey_image)
